# %% [markdown]
# <a href="https://colab.research.google.com/github/ntmHuong1510/LabCProgramming-Solution/blob/main/train_yolov5_aic22_track4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## READ THE DATA DRIVER AND MOUNT

# %%
# This will prompt for authorization.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##DOWNLOAD SYTHETIC DATA

# %%
#Install dependencies
! git clone https://github.com/ntmHuong1510/aic22sum-track4.git
# %cd /content/aic22sum-track4/processor/yolov5/

# %pip install -qr requirements.txt

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# Cloning into 'aic22sum-track4'...
# remote: Enumerating objects: 317, done.
# remote: Counting objects: 100% (317/317), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 317 (delta 153), reused 316 (delta 152), pack-reused 0
# Receiving objects: 100% (317/317), 7.40 MiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# /content
# aic22sum-track4  drive	sample_data

# %%
#Download from Google Drive (ONLY FOR GOOGLE DRIVE LINK)
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Md3yD4yrXv4X4d5qYk8ZqbikSlu7RmHy' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Md3yD4yrXv4X4d5qYk8ZqbikSlu7RmHy" -O label_coco.json && rm -rf /tmp/cookies.txt

#Download dataset1
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UoQprp03Z0z7BZaQHTOEZxwCPM9eKPA-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UoQprp03Z0z7BZaQHTOEZxwCPM9eKPA-" -O /content/aic22sum-track4/processor/yolov5/dataset1.zip && rm -rf /tmp/cookies.txt
# !unzip /content/aic22sum-track4/processor/yolov5/dataset1.zip
# Out:
# --2022-07-29 03:08:17--  https://docs.google.com/uc?export=download&confirm=&id=IwAR0Agp3b-t42smaaEu9NnAZ5aJoRA8EqecNGRiLjbO-gmvd-jN8P5OqOoyY
# Resolving docs.google.com (docs.google.com)... 173.194.218.139, 173.194.218.113, 173.194.218.102, ...
# Connecting to docs.google.com (docs.google.com)|173.194.218.139|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-07-29 03:08:17 ERROR 404: Not Found.
#
# --2022-07-29 03:08:17--  https://docs.google.com/uc?export=download&confirm=t&id=1UoQprp03Z0z7BZaQHTOEZxwCPM9eKPA-
# Resolving docs.google.com (docs.google.com)... 173.194.218.100, 173.194.218.101, 173.194.218.139, ...
# Connecting to docs.google.com (docs.google.com)|173.194.218.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# ...

# %%
from itertools import count
import shutil   # offers high-level operation on a file like a copy, create, and remote operation on the file
from os import listdir, path, rename
import cv2

fnames_train = listdir('validate_label')
source_train  = "validate_label/"
target_train = "validate_image/"


for fname in fnames_train:
    shutil.copyfile(source_train + fname, target_train + fname)

# %% [markdown]
# ##TRAIN DATA

# %%
# %cd ..
# !python train.py --img 640 --batch 16 --epochs 3 --data aic-track4.yaml --weights yolov5s.pt --noval
# Out:
# /content/aic22sum-track4/processor/yolov5
# train: weights=yolov5s.pt, cfg=, data=aic-track4.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=True, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-7-29 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# ...
